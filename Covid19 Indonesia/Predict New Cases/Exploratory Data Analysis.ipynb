# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Dataset\\covid19ind.csv")

df.head()
# Out:
#        Date Location ISO Code   Location  New Cases  New Deaths  \
# 0  3/2/2020               IDN  Indonesia          2           0
# 1  3/3/2020               IDN  Indonesia          0           0
# 2  3/4/2020               IDN  Indonesia          0           0
# 3  3/5/2020               IDN  Indonesia          0           0
# 4  3/6/2020               IDN  Indonesia          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2            2             0
# 1              0                 0            2             0
# 2              0                 0            2             0
# 3              0                 0            2             0
# 4              0                 2            4             0
#
#    Total Recovered  ...   Longitude  Latitude  New Cases per Million  \
# 0                0  ...  113.921327 -0.789275                   0.01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         392 non-null    object
#  1   Location ISO Code            392 non-null    object
#  2   Location                     392 non-null    object
#  3   New Cases                    392 non-null    int64
#  4   New Deaths                   392 non-null    int64
#  5   New Recovered                392 non-null    int64
#  6   New Active Cases             392 non-null    int64
#  7   Total Cases                  392 non-null    int64
#  8   Total Deaths                 392 non-null    int64
#  9   Total Recovered              392 non-null    int64
#  10  Total Active Cases           392 non-null    int64
#  11  Location Level               392 non-null    object
#  12  City or Regency              0 non-null      float64
# ...

# %%
df.describe()
# Out:
#           New Cases  New Deaths  New Recovered  New Active Cases  \
# count    392.000000  392.000000     392.000000        392.000000
# mean    3816.543367  103.186224    3396.428571        316.928571
# std     3430.093911   80.295512    3214.845931       1174.652931
# min        0.000000    0.000000       0.000000      -5003.000000
# 25%      927.250000   40.750000     501.000000          1.500000
# 50%     3268.000000   88.000000    2780.000000        266.500000
# 75%     5776.000000  142.750000    5127.250000        667.250000
# max    14518.000000  476.000000   13038.000000       5279.000000
#
#         Total Cases  Total Deaths  Total Recovered  Total Active Cases  \
# count  3.920000e+02    392.000000     3.920000e+02          392.000000
# mean   4.144783e+05  12652.413265     3.389658e+05        62860.186224
# std    4.594122e+05  12251.868637     3.977868e+05        52449.657703
# min    2.000000e+00      0.000000     0.000000e+00            2.000000
# ...

# %%
features = ["Longitude", "Latitude", "Area (km2)", 
            "Population", "Population Density", "Total Cities",
            "Time Zone", "Island", "Province", "City or Regency",
            "Total Regencies", "Total Districts", "Special Status",
            "Location Level", "Country", "Continent", "Total Urban Villages",
            "Total Rural Villages", "Location", "Location ISO Code"]

for feature in features:
    df.drop(columns=[feature], inplace=True)

# %%
df.head()
# Out:
#        Date  New Cases  New Deaths  New Recovered  New Active Cases  \
# 0  3/2/2020          2           0              0                 2
# 1  3/3/2020          0           0              0                 0
# 2  3/4/2020          0           0              0                 0
# 3  3/5/2020          0           0              0                 0
# 4  3/6/2020          2           0              0                 2
#
#    Total Cases  Total Deaths  Total Recovered  Total Active Cases  \
# 0            2             0                0                   2
# 1            2             0                0                   2
# 2            2             0                0                   2
# 3            2             0                0                   2
# 4            4             0                0                   4
#
#    New Cases per Million  Total Cases per Million  New Deaths per Million  \
# 0                   0.01                     0.01                     0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         392 non-null    object
#  1   New Cases                    392 non-null    int64
#  2   New Deaths                   392 non-null    int64
#  3   New Recovered                392 non-null    int64
#  4   New Active Cases             392 non-null    int64
#  5   Total Cases                  392 non-null    int64
#  6   Total Deaths                 392 non-null    int64
#  7   Total Recovered              392 non-null    int64
#  8   Total Active Cases           392 non-null    int64
#  9   New Cases per Million        392 non-null    float64
#  10  Total Cases per Million      392 non-null    float64
#  11  New Deaths per Million       392 non-null    float64
#  12  Total Deaths per Million     392 non-null    float64
# ...

# %%
features = ["Case Fatality Rate", "Case Recovered Rate"]


for feature in features:
    df[feature] = df[feature].str.split(pat="%", expand=True)[0]
    
    df[feature] = df[feature].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         392 non-null    object
#  1   New Cases                    392 non-null    int64
#  2   New Deaths                   392 non-null    int64
#  3   New Recovered                392 non-null    int64
#  4   New Active Cases             392 non-null    int64
#  5   Total Cases                  392 non-null    int64
#  6   Total Deaths                 392 non-null    int64
#  7   Total Recovered              392 non-null    int64
#  8   Total Active Cases           392 non-null    int64
#  9   New Cases per Million        392 non-null    float64
#  10  Total Cases per Million      392 non-null    float64
#  11  New Deaths per Million       392 non-null    float64
#  12  Total Deaths per Million     392 non-null    float64
# ...

# %%
df.describe()
# Out:
#           New Cases  New Deaths  New Recovered  New Active Cases  \
# count    392.000000  392.000000     392.000000        392.000000
# mean    3816.543367  103.186224    3396.428571        316.928571
# std     3430.093911   80.295512    3214.845931       1174.652931
# min        0.000000    0.000000       0.000000      -5003.000000
# 25%      927.250000   40.750000     501.000000          1.500000
# 50%     3268.000000   88.000000    2780.000000        266.500000
# 75%     5776.000000  142.750000    5127.250000        667.250000
# max    14518.000000  476.000000   13038.000000       5279.000000
#
#         Total Cases  Total Deaths  Total Recovered  Total Active Cases  \
# count  3.920000e+02    392.000000     3.920000e+02          392.000000
# mean   4.144783e+05  12652.413265     3.389658e+05        62860.186224
# std    4.594122e+05  12251.868637     3.977868e+05        52449.657703
# min    2.000000e+00      0.000000     0.000000e+00            2.000000
# ...

# %%
features_1 = ["New Cases", "New Deaths"]
features_2 = ["New Recovered", "New Active Cases"]

fig, ax = plt.subplots(figsize=(15, 9), ncols=2, nrows=2)

for i in range(2):
    sns.distplot(x=df[features_1[i]], ax=ax[i][0])
    
    ax[i][0].set_xlabel("")
    ax[i][0].set_title(f"Distribution of {features_1[i]} feature")
    
    sns.distplot(x=df[features_2[i]], ax=ax[i][1])
    
    ax[i][1].set_xlabel("")
    ax[i][1].set_title(f"Distribution of {features_2[i]} feature")
    
plt.show()
# Out:
# C:\Users\Bina Umat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Bina Umat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
features = ["Total Cases", "Total Deaths", "Total Recovered", "Total Active Cases"]

fig, ax = plt.subplots(figsize=(15, 9), nrows=2, ncols=2)

for i in range(2):
    sns.distplot(x=df[features[0:2][i]], ax=ax[i][0])
    
    ax[i][0].set_xlabel("")
    ax[i][0].set_title(f"Distribution of {features[0:2][i]} feature")
    
    sns.distplot(x=df[features[2:4][i]], ax=ax[i][1])
    
    ax[i][1].set_xlabel("")
    ax[i][0].set_title(f"Distribution of {features[2:4][i]} feature")
    
plt.show()
# Out:
# C:\Users\Bina Umat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Bina Umat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
features = ["New Cases per Million", "Total Cases per Million", "New Deaths per Million", "Total Deaths per Million"] 

fig, ax = plt.subplots(figsize=(15, 9), nrows=2, ncols=2)

for i in range(2):
    sns.distplot(x=df[features[0:2][i]], ax=ax[i][0])
    
    ax[i][0].set_xlabel("")
    ax[i][0].set_title(f"Distribution of {features[0:2][i]} feature")
    
    sns.distplot(x=df[features[2:4][i]], ax=ax[i][1])
    
    ax[i][1].set_xlabel("")
    ax[i][1].set_title(f"Distribution of {features[2:4][i]} feature")
    
plt.show()
# Out:
# C:\Users\Bina Umat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Bina Umat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
features = ["Case Fatality Rate", "Case Recovered Rate", "Growth Factor of New Cases", "Growth Factor of New Deaths"]

fig, ax = plt.subplots(figsize=(15, 9), nrows=2, ncols=2)

for i in range(2):
    sns.distplot(x=df[features[0:2][i]], ax=ax[i][0])
    
    ax[i][0].set_xlabel("")
    ax[i][0].set_title(f"Distribution of {features[0:2][i]} feature")
    
    sns.distplot(x=df[features[2:4][i]], ax=ax[i][1])
    
    ax[i][1].set_xlabel("")
    ax[i][1].set_title(f"Distribution of {features[2:4][i]} feature")
    
plt.show()
# Out:
# C:\Users\Bina Umat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Bina Umat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         392 non-null    object
#  1   New Cases                    392 non-null    int64
#  2   New Deaths                   392 non-null    int64
#  3   New Recovered                392 non-null    int64
#  4   New Active Cases             392 non-null    int64
#  5   Total Cases                  392 non-null    int64
#  6   Total Deaths                 392 non-null    int64
#  7   Total Recovered              392 non-null    int64
#  8   Total Active Cases           392 non-null    int64
#  9   New Cases per Million        392 non-null    float64
#  10  Total Cases per Million      392 non-null    float64
#  11  New Deaths per Million       392 non-null    float64
#  12  Total Deaths per Million     392 non-null    float64
# ...

# %%
# df.to_csv("Dataset\\Cleaned\\covid19ind_Cleaned.csv", index=False)

# %% [markdown]
# # Conclusion
#
# In this analysis we can conclude that every feature in this dataset is about case, death, recovery, and active class, this analysis conclude is about time to time about covid 19 in Indonesia. In this analysis there are a lot features like total of case, death, recovered, active class or about new case, death per million or about case fatality, recovered rate or about growth factor of new case, and death. There are a lot we can conclude from this dataset
